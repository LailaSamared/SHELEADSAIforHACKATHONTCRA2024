# %%
# import necessary libraries
import pandas as pdc

# %%
#load data
hdl = pd.read_csv('HDI-data.csv', encoding="latin-1")
hdl
# Out:
#                       Country Human development level Gender Inequality Index  \
# 0                 Switzerland               Very high                   0.018
# 1                      Norway               Very high                   0.012
# 2                     Iceland               Very high                   0.039
# 3      Hong Kong, China (SAR)               Very high                      ..
# 4                     Denmark               Very high                   0.009
# ..                        ...                     ...                     ...
# 188                      Chad                     Low                   0.671
# 189                     Niger                     Low                   0.609
# 190  Central African Republic                     Low                      ..
# 191               South Sudan                     Low                      ..
# 192                   Somalia                     Low                   0.674
#
# ...

# %%
hdl.head()
# Out:
#                   Country Human development level Gender Inequality Index  \
# 0             Switzerland               Very high                   0.018
# 1                  Norway               Very high                   0.012
# 2                 Iceland               Very high                   0.039
# 3  Hong Kong, China (SAR)               Very high                      ..
# 4                 Denmark               Very high                   0.009
#
#   Rank Maternal mortality ratio  Adolescent birth rate  \
# 0    3                        7                    2.2
# 1    2                        2                    2.2
# 2    9                        3                    5.1
# 3   ..                       ..                    1.6
# 4    1                        5                    1.8
#
#   Share of seats in parliament (% held by women) F_secondary_educ  \
# 0                                           39.0             96.9
# ...

# %%
hdl.shape
# Out:
# (193, 11)

# %%
# view data information
hdl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 11 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         193 non-null    object
#  1   Human development level                         193 non-null    object
#  2   Gender Inequality Index                         193 non-null    object
#  3   Rank                                            193 non-null    object
#  4   Maternal mortality ratio                        193 non-null    object
#  5   Adolescent birth rate                           193 non-null    float64
#  6   Share of seats in parliament (% held by women)  193 non-null    object
#  7   F_secondary_educ                                193 non-null    object
#  8   M_secondary_educ                                193 non-null    object
# ...

# %%
hdl.columns
# Out:
# Index(['Country', 'Human development level', 'Gender Inequality Index', 'Rank',
#        'Maternal mortality ratio', 'Adolescent birth rate',
#        'Share of seats in parliament (% held by women)', 'F_secondary_educ',
#        'M_secondary_educ', 'F_Labour_force', 'M_Labour_force'],
#       dtype='object')

# %%
#check for missing value
missing_values = hdl.isnull().sum()

missing_values
# Out:
# Country                                           0
# Human development level                           0
# Gender Inequality Index                           0
# Rank                                              0
# Maternal mortality ratio                          0
# Adolescent birth rate                             0
# Share of seats in parliament (% held by women)    0
# F_secondary_educ                                  0
# M_secondary_educ                                  0
# F_Labour_force                                    0
# M_Labour_force                                    0
# dtype: int64

# %%
#convert datatype
cols_to_convert = ['Gender Inequality Index', 'Rank', 'Maternal mortality ratio',
                   'Adolescent birth rate', 'F_secondary_educ', 'M_secondary_educ',
                   'F_Labour_force', 'M_Labour_force','Share of seats in parliament (% held by women)']

for col in cols_to_convert:
    hdl[col] = pd.to_numeric(hdl[col], errors='coerce')
hdl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 11 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         193 non-null    object
#  1   Human development level                         193 non-null    object
#  2   Gender Inequality Index                         166 non-null    float64
#  3   Rank                                            166 non-null    float64
#  4   Maternal mortality ratio                        180 non-null    float64
#  5   Adolescent birth rate                           193 non-null    float64
#  6   Share of seats in parliament (% held by women)  191 non-null    float64
#  7   F_secondary_educ                                178 non-null    float64
#  8   M_secondary_educ                                178 non-null    float64
# ...

# %%
#check the missing value again
hdl.isnull().sum()
# Out:
# Country                                            0
# Human development level                            0
# Gender Inequality Index                           27
# Rank                                              27
# Maternal mortality ratio                          13
# Adolescent birth rate                              0
# Share of seats in parliament (% held by women)     2
# F_secondary_educ                                  15
# M_secondary_educ                                  15
# F_Labour_force                                    11
# M_Labour_force                                    11
# dtype: int64

# %%
#fill the missing value
cols_to_fill = ['Gender Inequality Index', 'Rank', 'Maternal mortality ratio',
                'F_secondary_educ', 'M_secondary_educ', 'F_Labour_force', 'M_Labour_force','Share of seats in parliament (% held by women)']

for col in cols_to_fill:
    hdl[col] = hdl[col].fillna(hdl[col].median())
hdl.isnull().sum()
# Out:
# Country                                           0
# Human development level                           0
# Gender Inequality Index                           0
# Rank                                              0
# Maternal mortality ratio                          0
# Adolescent birth rate                             0
# Share of seats in parliament (% held by women)    0
# F_secondary_educ                                  0
# M_secondary_educ                                  0
# F_Labour_force                                    0
# M_Labour_force                                    0
# dtype: int64

# %% [markdown]
# ### EDA

# %%
# basic statistical analysis
hdl.describe()
# Out:
#        Gender Inequality Index        Rank  Maternal mortality ratio  \
# count               193.000000  193.000000                193.000000
# mean                  0.336990   83.479275                123.704663
# std                   0.180681   44.549681                165.477217
# min                   0.009000    1.000000                  1.000000
# 25%                   0.190000   49.000000                 14.000000
# 50%                   0.351000   83.500000                 58.000000
# 75%                   0.477000  118.000000                173.000000
# max                   0.820000  166.000000                835.000000
#
#        Adolescent birth rate  Share of seats in parliament (% held by women)  \
# count             193.000000                                      193.000000
# mean               44.170466                                       25.222280
# std                37.865333                                       12.196288
# ...

# %% [markdown]
# ### destribution of data

# %%
# Analyze the distribution of review ratings
plt.figure(figsize=(10, 6))
sns.histplot(data=hdl, x='Gender Inequality Index', bins=5, kde=True)
plt.xlabel('Gender Inequality Index')
plt.ylabel('Count')
plt.title('Distribution of Gender Inequality Index')
plt.tight_layout()
plt.show()

# %%
# Analyze the distribution of Adolescent birth rate
plt.figure(figsize=(10, 6))
sns.histplot(data=hdl, x='Adolescent birth rate', bins=5, kde=True)
plt.xlabel('Adolescent birth rate')
plt.ylabel('Count')
plt.title('Distribution of Adolescent birth rate')
plt.tight_layout()
plt.show()

# %%
# Analyze the distribution of Rank
plt.figure(figsize=(10, 6))
sns.histplot(data=hdl, x='Rank', bins=5, kde=True)
plt.xlabel('Rank')
plt.ylabel('Count')
plt.title('Distribution of Rank')
plt.tight_layout()
plt.show()

# %%
#correlation
numeric_columns = ['Gender Inequality Index', 'Rank',
       'Maternal mortality ratio', 'Adolescent birth rate',
       'Share of seats in parliament (% held by women)', 'F_secondary_educ',
       'M_secondary_educ', 'F_Labour_force', 'M_Labour_force']
correlation_matrix = hdl[numeric_columns].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
level_counts = hdl['Human development level'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(level_counts, labels=level_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Human Development Levels')
plt.show()

# %% [markdown]
# ### Gender Inequality Index of Countries with  Human Development Level

# %%
# Filter the data for countries with 'Very high' Human Development Level
very_high_hdi = hdl[hdl['Human development level'] == 'Very high']
# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(very_high_hdi['Country'], very_high_hdi['Gender Inequality Index'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Gender Inequality Index')
plt.title('Gender Inequality Index of Countries with Very High Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the data for countries with 'High' Human Development Level
high_hdi = hdl[hdl['Human development level'] == 'High']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(high_hdi['Country'], high_hdi['Gender Inequality Index'], color='lightcoral')
plt.xlabel('Country')
plt.ylabel('Gender Inequality Index')
plt.title('Gender Inequality Index of Countries with High Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the data for countries with 'Medium' Human Development Level
medium_hdi = hdl[hdl['Human development level'] == 'Medium']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(medium_hdi['Country'], medium_hdi['Gender Inequality Index'], color='brown')
plt.xlabel('Country')
plt.ylabel('Gender Inequality Index')
plt.title('Gender Inequality Index of Countries with Medium Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the data for countries with 'low' Human Development Level
medium_hdi = hdl[hdl['Human development level'] == 'Low']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(medium_hdi['Country'], medium_hdi['Gender Inequality Index'], color='green')
plt.xlabel('Country')
plt.ylabel('Gender Inequality Index')
plt.title('Gender Inequality Index of Countries with low Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## insights

# %% [markdown]
# ### Female Mean Years of Schooling of Countries with Human Development Level

# %%
# Filter the data for countries with 'very high' Human Development Level
medium_hdi = hdl[hdl['Human development level'] == 'Very high']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(medium_hdi['Country'], medium_hdi['F_secondary_educ'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('Female Mean Years of Schooling')
plt.title('Female Mean Years of Schooling of Countries with Very high Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the data for countries with 'high' Human Development Level
medium_hdi = hdl[hdl['Human development level'] == 'High']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(medium_hdi['Country'], medium_hdi['F_secondary_educ'], color='green')
plt.xlabel('Country')
plt.ylabel('Female Mean Years of Schooling')
plt.title('Female Mean Years of Schooling of Countries with high Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the data for countries with 'Medium' Human Development Level
medium_hdi = hdl[hdl['Human development level'] == 'Medium']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(medium_hdi['Country'], medium_hdi['F_secondary_educ'], color='pink')
plt.xlabel('Country')
plt.ylabel('Female Mean Years of Schooling')
plt.title('Female Mean Years of Schooling of Countries with Medium Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the data for countries with 'low' Human Development Level
medium_hdi = hdl[hdl['Human development level'] == 'Low']

# Create a bar graph
plt.figure(figsize=(12, 6))
plt.bar(medium_hdi['Country'], medium_hdi['F_secondary_educ'], color='blue')
plt.xlabel('Country')
plt.ylabel('Female Mean Years of Schooling')
plt.title('Female Mean Years of Schooling of Countries with low Human Development Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### insights

# %%
###

# %%
# Group data by Human development level and calculate mean Adolescent birth rate
adolescent_birth_rate = hdl.groupby('Human development level')['Adolescent birth rate'].mean().reset_index()

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(adolescent_birth_rate['Human development level'], adolescent_birth_rate['Adolescent birth rate'], color='skyblue')
plt.xlabel('Human Development Level')
plt.ylabel('Adolescent Birth Rate')
plt.title('Average Adolescent Birth Rate by Human Development Level')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
###

# %%
# Group data by Human development level and calculate mean Maternal mortality ratio
maternal_mortality_ratio = hdl.groupby('Human development level')['Maternal mortality ratio'].mean().reset_index()

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(maternal_mortality_ratio['Human development level'], maternal_mortality_ratio['Maternal mortality ratio'], color='lightcoral')
plt.xlabel('Human Development Level')
plt.ylabel('Maternal Mortality Ratio')
plt.title('Average Maternal Mortality Ratio by Human Development Level')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
###

# %%
# Group data by Human development level and calculate mean Maternal mortality ratio
maternal_mortality_ratio = hdl.groupby('Human development level')['Share of seats in parliament (% held by women)'].mean().reset_index()

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(maternal_mortality_ratio['Human development level'], maternal_mortality_ratio['Share of seats in parliament (% held by women)'], color='lightcoral')
plt.xlabel('Human Development Level')
plt.ylabel('Share of seats in parliament (% held by women)')
plt.title('Average Share of seats in parliament (% held by women) by Human Development Level')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tanzania's Human Development Indicators

# %%
tanzania_data = hdl[hdl['Country'] == 'Tanzania (United Republic of)']
plt.figure(figsize=(12, 8))

# Gender Inequality Index
plt.bar('Gender Inequality Index', tanzania_data['Gender Inequality Index'], color='b', alpha=0.7, label='Gender Inequality Index')

# Maternal Mortality Ratio
plt.bar('Maternal mortality ratio', tanzania_data['Maternal mortality ratio'], color='r', alpha=0.7, label='Maternal Mortality Ratio')

# Adolescent Birth Rate
plt.bar('Adolescent birth rate', tanzania_data['Adolescent birth rate'], color='g', alpha=0.7, label='Adolescent Birth Rate')

# Female Secondary Education
plt.bar('F_secondary_educ', tanzania_data['F_secondary_educ'], color='y', alpha=0.7, label='Female Secondary Education')

plt.xlabel('Indicator')
plt.ylabel('Value')
plt.title('Comparison of Tanzania\'s Human Development Indicators')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
tanzania_data
# Out:
#                            Country Human development level  \
# 166  Tanzania (United Republic of)                     Low
#
#      Gender Inequality Index   Rank  Maternal mortality ratio  \
# 166                    0.513  131.0                     238.0
#
#      Adolescent birth rate  Share of seats in parliament (% held by women)  \
# 166                  123.4                                            36.9
#
#      F_secondary_educ  M_secondary_educ  F_Labour_force  M_Labour_force
# 166               9.3              14.3            75.5            84.5
